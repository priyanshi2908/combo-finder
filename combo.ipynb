# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshi2908/combo-finder/blob/main/combo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem Statement:

#Find all the list of products whose sum-of-price is between 290 and 310.

#ProductList = {p1:10, p2:15, p3:20, p4:25, p5:30, p6:35, p7:50}
import random as r
PL = {"p1":10, "p2":15, "p3":20, "p4":25, "p5":30, "p6":35, "p7":50}
v=list(PL.values())
p=list(PL.keys())
l1=[]
for j in range(1,1001):
 k=r.randint(2,7)
 ComboList = r.sample(p,k)
 ComboSum = sum([PL[i] for i in ComboList])
 if ComboSum>=100 and ComboSum<=120:
  print(ComboList)
# Out:
# ['p7', 'p3', 'p5']
# ['p4', 'p5', 'p7', 'p1']
# ['p5', 'p7', 'p6']
# ['p3', 'p5', 'p7']
# ['p6', 'p4', 'p7']
# ['p3', 'p6', 'p5', 'p4']
# ['p6', 'p7', 'p1', 'p3']
# ['p3', 'p7', 'p2', 'p4']
# ['p3', 'p4', 'p7', 'p1']
# ['p6', 'p7', 'p1', 'p3']
# ['p1', 'p3', 'p6', 'p4', 'p2']
# ['p7', 'p5', 'p3']
# ['p6', 'p1', 'p3', 'p7']
# ['p6', 'p7', 'p2']
# ['p4', 'p5', 'p7']
# ['p2', 'p4', 'p3', 'p1', 'p6']
# ['p1', 'p7', 'p5', 'p2']
# ['p1', 'p7', 'p3', 'p4']
# ['p6', 'p5', 'p2', 'p3']
# ['p3', 'p1', 'p6', 'p7']
# ['p7', 'p5', 'p6']
# ['p6', 'p7', 'p3']
# ['p1', 'p3', 'p7', 'p4']
# ['p6', 'p1', 'p2', 'p3', 'p5']
# ['p1', 'p5', 'p3', 'p6', 'p2']
# ['p5', 'p3', 'p2', 'p7']
# ['p4', 'p5', 'p7', 'p1']
# ['p7', 'p4', 'p3', 'p2']
# ['p1', 'p4', 'p2', 'p7', 'p3']
# ['p4', 'p1', 'p6', 'p7']
# ['p7', 'p3', 'p1', 'p5']
# ['p6', 'p2', 'p7']
# ['p3', 'p7', 'p5']
# ['p3', 'p4', 'p7', 'p1', 'p2']
# ['p1', 'p6', 'p4', 'p7']
# ['p7', 'p4', 'p3', 'p2', 'p1']
# ['p3', 'p6', 'p7']
# ['p5', 'p3', 'p7']
# ...
